# %%
library(tidyverse)
library(repr)
library(tidymodels)

# %% [markdown]
# The 'players' dataset has:
# - 196 observations
# - 7 variables:
#     - experience, a word representing the player's prior experience with Minecraft, ranging from 'Beginner' to 'Pro'
#     - subscribe, a boolean denoting whether or not the player has subscribed to the game-related newsletter
#     - hashedEmail, a scrambled version of the player's email
#     - played_hours, the amount of time the player has spent on the Minecraft server in hours, rounded to one decimal place
#     - name, the player's name
#     - gender, the player's gender
#     - age, the player's age in years

# %%
# table <- matrix(c('string','boolean','string','double','string','string','integer'), ncol=7, byrow=TRUE)
# colnames(tab) <- c('experience','subscribe','hashedEmail','played_hours','name','gender','age')
# rownames(tab) <- c('type','meaning','summary statistics')
# table <- as.table(tab)
# table

tab <- matrix(c('a', 5, 14, 19, 3, 2, 17, 6, 12), ncol=7, byrow=TRUE)
colnames(tab) <- c('colName1','colName2','colName3')
rownames(tab) <- c('rowName1','rowName2','rowName3')
tab <- as.table(tab)
tab
